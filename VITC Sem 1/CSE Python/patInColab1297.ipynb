# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #1. Read the csv file 'california.csv' and insert two rows as below
# ###### -115,37.56,31,4500,145,6666,6660,6.5465,345700,o
# ###### -115,39.34,32,4501,146,6667,6656,5.3456,345956,o

# %%
cal = pd.read_csv('california.csv',sep=',',index_col=None)

# %%
dict1={'longitude':[-115,-115],'latitude':[37.56,39.34],'housing_median_age':[31,32],'total_rooms':[4500,4501],'total_bedrooms':[145,146],'population':[6666,6667],'households':[6660,6656],'median_income':[6.5465,5.3456],'median_house_value':[345700,345956],'occupied':['o','o']}
df=pd.DataFrame(dict1)
cal = pd.concat([cal, df], ignore_index = True)

# %% [markdown]
# #2. Display the first 6 rows of the table (including header)

# %%
cal.head()
# Out:
#    longitude  latitude  ...  median_house_value  occupied
# 0    -122.05     37.37  ...              344700         o
# 1    -118.30     34.26  ...              176500       NaN
# 2    -117.81     33.78  ...              270500       NaN
# 3    -118.36     33.82  ...              330000         o
# 4    -119.67     36.33  ...               81700       NaN
#
# [5 rows x 10 columns]

# %% [markdown]
# #3. Display the last 9 rows of the table

# %%
cal.tail(9)
# Out:
#     longitude  latitude  ...  median_house_value  occupied
# 47    -118.29     33.94  ...              105700       NaN
# 48    -121.35     38.00  ...              123800       NaN
# 49    -117.99     33.78  ...              173900       NaN
# 50    -120.99     37.70  ...              160900       NaN
# 51    -119.42     35.97  ...               47500       NaN
# 52    -122.21     37.80  ...              156500       NaN
# 53    -118.17     33.80  ...              187500         o
# 54    -115.00     37.56  ...              345700         o
# 55    -115.00     39.34  ...              345956         o
#
# [9 rows x 10 columns]

# %% [markdown]
# #4. Display the maximum value for each house value.
#
# #### Expected output
# ![q4.jpg](data:image/jpeg;base64,...)

# %%
cal.groupby('housing_median_age')['median_house_value'].max()
# Out:
# housing_median_age
# 4     237500
# 5     141800
# 6     123800
# 11    232200
# 13    150700
# 14    160900
# 15    194400
# 16    275000
# 17    128900
# 19    350000
# 21     47500
# 24    212500
# 26    300000
# 27    344700
# 28    330000
# 30    425000
# 31    345700
# 32    369200
# 33    178700
# 34    185300
# 35    414300
# 36    484700
# 37    500001
# 38    183800
# 39    156500
# 40    126300
# 42    153100
# 43    176500
# 45    125000
# 47    241500
# 48    214800
# 52    270800
# Name: median_house_value, dtype: int64

# %% [markdown]
# #5. Display the maximum value among all the housing value
# #### Expected output
# 500001

# %%
cal['median_house_value'].max()
# Out:
# 500001

# %% [markdown]
# #6. Find the average value of each house based on the value
# ##### Expected Output
# 205816.0892857143

# %%
cal['median_house_value'].mean()
# Out:
# 205820.6607142857

# %% [markdown]
# #7. Replace the null value in occupied as 'F' and display the count of the value
# #### Expected Output
# ![q7.jpg](data:image/jpeg;base64,...)

# %%
cal['occupied'] = cal['occupied'].fillna('F')
cal['occupied'].value_counts()
# Out:
# F    48
# o     8
# Name: occupied, dtype: int64

# %% [markdown]
# #8. Create a sub dataframe with only occupied results
# ![q8.jpg](data:image/jpeg;base64,...)

# %%
df=cal[(cal['occupied']=='o')]
df
# Out:
#     longitude  latitude  ...  median_house_value  occupied
# 0     -122.05     37.37  ...              344700         o
# 3     -118.36     33.82  ...              330000         o
# 11    -119.12     35.85  ...               58300         o
# 21    -121.37     38.68  ...               83400         o
# 32    -121.13     39.31  ...              128900         o
# 53    -118.17     33.80  ...              187500         o
# 54    -115.00     37.56  ...              345700         o
# 55    -115.00     39.34  ...              345956         o
#
# [8 rows x 10 columns]

# %% [markdown]
# #9. Select the housing details where house value is greater than 410000
#
# ![q9.jpg](data:image/jpeg;base64,...)

# %%
df1=cal[(cal['median_house_value']>410000)]
df1
# Out:
#     longitude  latitude  ...  median_house_value  occupied
# 19    -122.59     38.01  ...              414300         F
# 25    -118.03     34.16  ...              484700         F
# 29    -118.48     34.01  ...              425000         F
# 42    -118.06     34.15  ...              500001         F
#
# [4 rows x 10 columns]

# %% [markdown]
# #10. Insert a new column location and display 5 records default value as California.
# ![q10.jpg](data:image/jpeg;base64,...)

# %%
cal.insert(2,'location','California')
cal.head()
# Out:
#    longitude  latitude    location  ...  median_income  median_house_value  occupied
# 0    -122.05     37.37  California  ...         6.6085              344700         o
# 1    -118.30     34.26  California  ...         3.5990              176500         F
# 2    -117.81     33.78  California  ...         5.7934              270500         F
# 3    -118.36     33.82  California  ...         6.1359              330000         o
# 4    -119.67     36.33  California  ...         2.9375               81700         F
#
# [5 rows x 11 columns]
